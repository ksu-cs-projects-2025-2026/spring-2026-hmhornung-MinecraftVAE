# %%
import os
import numpy
import amulet
from amulet.api.selection import SelectionGroup, SelectionBox
# Out:
# INFO - PyMCTranslate Version 378

# %%
import amulet

saves_path = 'C:/Users/hmhor/AppData/Roaming/.minecraft/saves'

world_path = os.path.join(saves_path, "Arnis World 13/region/r.0.0.mca")
world = amulet.load_level(world_path)

# box = SelectionBox((0, 64, 0), (10, 74, 10))
# selection = SelectionGroup(box)

# target_path = "output_schematic.construction"

# world.extract_structure(selection, target_path)

# world.close()
# Out:
# INFO - Loading level C:/Users/hmhor/AppData/Roaming/.minecraft/saves\Arnis World 13/region/r.0.0.mca
# ---------------------------------------------------------------------------
# LoaderNoneMatched                         Traceback (most recent call last)
# Cell In[2], line 6
#       3 saves_path = 'C:/Users/hmhor/AppData/Roaming/.minecraft/saves'
#       5 world_path = os.path.join(saves_path, "Arnis World 13/region/r.0.0.mca")
# ----> 6 world = amulet.load_level(world_path)
#       8 # box = SelectionBox((0, 64, 0), (10, 74, 10))
#       9 # selection = SelectionGroup(box)
#      10
#    (...)     14
#      15 # world.close()
#
# File h:\Projects\spring-2026-hmhornung-MinecraftVAE\data_processing\.venv\Lib\site-packages\amulet\level\load.py:30, in load_level(path)
#      15 """
#      16 Load and return a :class:`World` or :class:`Structure` class exposing the data at ``path``
#      17
#    (...)     27     Exception: Other errors.
#      28 """
# ...

# %%
dim = world.dimensions[0]

# %%
for i in range(-64, 320):
    print(world.get_block(800,i,800, dim))
# Out:
# universal_minecraft:air
# universal_minecraft:air
# universal_minecraft:air
# universal_minecraft:air
# universal_minecraft:air
# universal_minecraft:air
# universal_minecraft:air
# universal_minecraft:air
# universal_minecraft:air
# universal_minecraft:air
# universal_minecraft:air
# universal_minecraft:air
# universal_minecraft:air
# universal_minecraft:air
# universal_minecraft:air
# universal_minecraft:air
# universal_minecraft:air
# universal_minecraft:air
# universal_minecraft:air
# universal_minecraft:air
# universal_minecraft:air
# universal_minecraft:air
# universal_minecraft:air
# universal_minecraft:air
# universal_minecraft:air
# universal_minecraft:air
# universal_minecraft:air
# universal_minecraft:air
# universal_minecraft:air
# universal_minecraft:air
# universal_minecraft:air
# universal_minecraft:air
# universal_minecraft:air
# universal_minecraft:air
# universal_minecraft:air
# universal_minecraft:air
# universal_minecraft:air
# universal_minecraft:air
# ...

# %%
world.close()
